# %%
#Lista = Vectores en python: sus datos son editables
list = [1, 2, "a", "b", 5]

#Tupla: sus datos no se pueden cambiar
tuple = (1, 2, 3, 4, 5)

#Conjunto: sus datos no se pueden repetir
conjunto = {1, 2, 3, 4, 5}

#Diccionarios: llave mas un valor
dictionary= {"name":"Adrián", "age": 14}

# %%
import numpy as np
#matrices

# %%
#Pilas
class Pila():
    def __init__(self):
        self.elementos = []

    def apilar(self, elemento):
        self.elementos.append(elemento)

    def desapilar(self)
        if not self.esta_vacia():
           | self.elementos.pop()

    def esta_vacia(self):
        return len(self.elementos)==0

# %%
#Colas
from collections import deque

class Cola:
    def __init__(self):
        self.elementos = deque()

    def encolar(self, elemento):
        self.elementos.append(elemento)

    def desencolar(self):
        if not self.esta_vacia():
            return self.elementos.popleft()
        return None
    def esta_vacia(self):
        return len(self.elementos)==0

cola= Cola()
cola.encolar(9)
cola.encolar(8)
cola.encolar(10)
cola.desencolar()

# %%
class Nodo:
    def __init__(self, valor):
        self.valor = valor
        self.siguiente = None
class ListaEnlazada:
    def __init__(self):
        self.cabeza = None

    def agregar(self, valor):
        nuevo_nodo = Nodo(valor)
        if self.cabeza is None:
            self.cabeza = nuevo_nodo
        else:
            nodo_actual = self.cabeza
            while nodo_actual.siguiente:
                nodo_actual = nodo_actual.siguiente
            nodo_actual.siguiente = nuevo_nodo
            print()

    def mostrar(self):
        nodo_actual = self.cabeza
        while nodo_actual:
            print(nodo_actual.valor, end=" ->")
            nodo_actual = nodo_actual.siguiente
        print()


    def buscar(self, valor):
        nodo_actual = self.cabeza
        while nodo_actual:
            if nodo_actual.valor == valor:
                return True
            nodo_actual = nodo_actual.siguiente
        return False

listaEnlazada = ListaEnlazada()
listaEnlazada.agregar(1)
listaEnlazada.agregar(2)
listaEnlazada.agregar(3)
listaEnlazada.mostrar()
print(listaEnlazada.buscar(2))
print(listaEnlazada.buscar(9))
# Out:
# 1 ->2 ->3 ->
# True
# False

# %%
import re

banco_respuestas = {
    "saludos": [
        "Hola, estoy aquí para ayudarte",
        "Saludos, estaré contento de ayudarte"
    ],
    "instituciones": [
        {
            "ministerios": {
                "Trabajo": [
                    {
                        "procedimiento1": {
                            "nombre": "Solicitud de permiso de trabajo",
                            "requisitos": ["cédula", "carta de oferta laboral", "certificado de antecedentes penales"]
                        },
                        "procedimiento2": {
                            "nombre": "Inscripción en el Registro de Trabajadores",
                            "requisitos": ["cédula", "formulario de inscripción", "constancia de residencia"]
                        }
                    }
                ],
                "Educación": [
                    {
                        "procedimiento1": {
                            "nombre": "Inscripción en el sistema educativo",
                            "requisitos": ["cédula", "acta de nacimiento", "ficha médica"]
                        },
                        "procedimiento2": {
                            "nombre": "Solicitud de beca",
                            "requisitos": ["cédula", "documentos que acrediten situación económica", "carta de motivación"]
                        }
                    }
                ]
            }
        },
        {
            "alcaldías": {
                "Panamá": [
                    {
                        "procedimiento1": {
                            "nombre": "Solicitud de licencia de construcción",
                            "requisitos": ["cédula", "planos de construcción", "permiso ambiental"]
                        },
                        "procedimiento2": {
                            "nombre": "Inscripción en el registro de comerciantes",
                            "requisitos": ["cédula", "licencia comercial anterior", "documentación fiscal"]
                        }
                    }
                ],
                "San Miguelito": [
                    {
                        "procedimiento1": {
                            "nombre": "Solicitud de mantenimiento de vías",
                            "requisitos": ["cédula", "planos del área", "propuesta de trabajo"]
                        },
                        "procedimiento2": {
                            "nombre": "Registro de propiedad",
                            "requisitos": ["cédula", "escritura de propiedad", "certificado de pago de impuestos"]
                        }
                    }
                ]
            }
        }
    ]
}
